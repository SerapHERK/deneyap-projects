# %%
import pandas as pd

# Verileri tabloya yükleyelim
data = {
    "EMG 1 (mV)": [-1.7317006, -2.1409171, -2.643122, -3.153048, -3.6294041, -4.0698405, -4.4906386],
    "ACC X (G) S1": [-2.9414062, 0, -0.3359375, 0.1289062, 0.4648438, 0.3828125, -0.1015625],
    "ACC Y (G) S1": [1.859375, 0, 0.2851562, 0.3046875, 0.5429688, 0.7460938, 0.9765625],
    "ACC Z (G) S1": [-0.0234375, 0, 0.0585938, -0.015625, -0.1171875, -0.1328125, -0.171875],
    "GYRO X (deg/s) S1": [35.6097565, 0, -53.1707344, -45.3658562, -43.9024391, -73.1707306, -74.1463394],
    "GYRO Y (deg/s) S1": [204.8780518, 0, -12.6829271, -79.5121994, -97.0731735, -112.68293, -78.0487823],
    "GYRO Z (deg/s) S1": [-115.1219559, 0, -46.341465, -12.6829271, -8.780488, 2.9268293, 20],
    "EMG 1 (mV) S2": [0.0058747, 0.0125887, 0.0162814, 0.0166171, 0.0132601, 0.0077211, 0.0015106],
    "ACC X (G) S2": [0.9375, 0.3476562, -0.0195312, -0.6171875, -0.8046875, -0.9609375, -0.9726562],
    "ACC Y (G) S2": [1.7109375, 0.7578125, -0.0078125, -0.640625, -0.515625, -0.21875, 0.5820312],
    "ACC Z (G) S2": [0.5117188, 0.125, -0.3203125, -0.578125, -0.4453125, -0.3710938, -0.3320312],
    "GYRO X (deg/s) S2": [-66.8292694, -71.7073212, -80, -69.2682953, -26.3414631, 27.8048782, 81.4634171],
    "GYRO Y (deg/s) S2": [63.9024391, 86.8292694, 118.5365906, 80, 45.8536606, 44.3902435, 37.5609779],
    "GYRO Z (deg/s) S2": [-2.9268293, 4.390244, 37.5609779, 69.2682953, 66.3414612, 38.5365868, 0]
}

# DataFrame oluşturma
df = pd.DataFrame(data)

# Min-max normalizasyon fonksiyonu
def min_max_normalize(column):
    return (column - column.min()) / (column.max() - column.min())

# Verileri normalize edelim
df_normalized = df.apply(min_max_normalize)

# Normalize edilmiş verileri ekrana yazdırma
print(df_normalized)
# Out:
#    EMG 1 (mV)  ACC X (G) S1  ACC Y (G) S1  ACC Z (G) S1  GYRO X (deg/s) S1  \
# 0    1.000000      0.000000      1.000000      0.644068           1.000000
# 1    0.851676      0.863532      0.000000      0.745763           0.675556
# 2    0.669648      0.764908      0.153361      1.000000           0.191111
# 3    0.484821      0.901376      0.163866      0.677966           0.262222
# 4    0.312162      1.000000      0.292017      0.237288           0.275556
# 5    0.152522      0.975917      0.401261      0.169491           0.008889
# 6    0.000000      0.833716      0.525210      0.000000           0.000000
#
#    GYRO Y (deg/s) S1  GYRO Z (deg/s) S1  EMG 1 (mV) S2  ACC X (G) S2  \
# 0           1.000000           0.000000       0.288889      1.000000
# 1           0.354839           0.851986       0.733333      0.691207
# 2           0.314900           0.509025       0.977778      0.498978
# 3           0.104455           0.758123       1.000000      0.186094
# ...
